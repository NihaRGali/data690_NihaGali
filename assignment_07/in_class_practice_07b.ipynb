# %% [markdown]
# <a href="https://colab.research.google.com/github/NihaRGali/data690_NihaGali/blob/main/assignment_07/in_class_practice_07b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In-class Practice Session 7
# Professor : Wang
#
# Student   : Niha Reddy Gali
#
# Date      : 10/14/2021

# %%
import pandas as pd
print("Pandas version is:",pd.__version__)

import plotly
print(plotly.__version__)
import plotly.graph_objects as go
import plotly.express as px
# Out:
# Pandas version is: 1.1.5
# 4.4.1

# %%
df = pd.read_csv("/content/wdi_data (1).csv")
df.head(10)
# Out:
#    Unnamed: 0  Year  ...         Income Group Lending Type
# 0           0  2015  ...           Low income          IDA
# 1           1  2016  ...           Low income          IDA
# 2           2  2017  ...           Low income          IDA
# 3           3  2018  ...           Low income          IDA
# 4           4  2019  ...           Low income          IDA
# 5           5  2020  ...           Low income          IDA
# 6           6  2015  ...  Upper middle income         IBRD
# 7           7  2016  ...  Upper middle income         IBRD
# 8           8  2017  ...  Upper middle income         IBRD
# 9           9  2018  ...  Upper middle income         IBRD
#
# [10 rows x 9 columns]

# %%
#df.drop(columns=["unnamed:0"], inplace=True)
df_new =df.drop(columns=["Unnamed: 0"])
df_new.head()
# Out:
#    Year        value          indicator  ...      Region Income Group Lending Type
# 0  2015  2087.305323  NY.GDP.PCAP.PP.CD  ...  South Asia   Low income          IDA
# 1  2016  1981.118069  NY.GDP.PCAP.PP.CD  ...  South Asia   Low income          IDA
# 2  2017  2058.400221  NY.GDP.PCAP.PP.CD  ...  South Asia   Low income          IDA
# 3  2018  2082.635648  NY.GDP.PCAP.PP.CD  ...  South Asia   Low income          IDA
# 4  2019  2152.366489  NY.GDP.PCAP.PP.CD  ...  South Asia   Low income          IDA
#
# [5 rows x 8 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  Year        value  ...      Region Income Group Lending Type
# 0           0  2015  2087.305323  ...  South Asia   Low income          IDA
# 1           1  2016  1981.118069  ...  South Asia   Low income          IDA
# 2           2  2017  2058.400221  ...  South Asia   Low income          IDA
# 3           3  2018  2082.635648  ...  South Asia   Low income          IDA
# 4           4  2019  2152.366489  ...  South Asia   Low income          IDA
#
# [5 rows x 9 columns]

# %%
#df_ind = df_new.query(""Country Code'=="IND") #not working becauase of space btw the column name
df_ind_bra = df_new[df_new["Country Code"].isin(['IND','BRA'])]
df_ind_bra
# Out:
#       Year         value  ...         Income Group Lending Type
# 140   2015  1.474411e+04  ...  Upper middle income         IBRD
# 141   2016  1.425616e+04  ...  Upper middle income         IBRD
# 142   2017  1.452461e+04  ...  Upper middle income         IBRD
# 143   2018  1.502044e+04  ...  Upper middle income         IBRD
# 144   2019  1.538823e+04  ...  Upper middle income         IBRD
# 145   2020  1.483631e+04  ...  Upper middle income         IBRD
# 462   2015  5.464859e+03  ...  Lower middle income         IBRD
# 463   2016  5.839865e+03  ...  Lower middle income         IBRD
# 464   2017  6.182922e+03  ...  Lower middle income         IBRD
# 465   2018  6.675361e+03  ...  Lower middle income         IBRD
# 466   2019  6.997864e+03  ...  Lower middle income         IBRD
# 467   2020  6.454347e+03  ...  Lower middle income         IBRD
# 1265  2015  7.499400e+01  ...  Upper middle income         IBRD
# 1266  2016  7.523000e+01  ...  Upper middle income         IBRD
# ...

# %%
df_gdp = df.query("indicator == 'NY.GDP.PCAP.PP.CD'	")
df_gdp
# Out:
#       Unnamed: 0  Year  ...         Income Group Lending Type
# 0              0  2015  ...           Low income          IDA
# 1              1  2016  ...           Low income          IDA
# 2              2  2017  ...           Low income          IDA
# 3              3  2018  ...           Low income          IDA
# 4              4  2019  ...           Low income          IDA
# ...          ...   ...  ...                  ...          ...
# 1140        1140  2016  ...  Lower middle income        Blend
# 1141        1141  2017  ...  Lower middle income        Blend
# 1142        1142  2018  ...  Lower middle income        Blend
# 1143        1143  2019  ...  Lower middle income        Blend
# 1144        1144  2020  ...  Lower middle income        Blend
#
# [1145 rows x 9 columns]

# %%
df_ind_gdpcap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 462 to 467
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6 non-null      int64
#  1   Year          6 non-null      int64
#  2   value         6 non-null      float64
#  3   indicator     6 non-null      object
#  4   Country Code  6 non-null      object
#  5   Country Name  6 non-null      object
#  6   Region        6 non-null      object
#  7   Income Group  6 non-null      object
#  8   Lending Type  6 non-null      object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 480.0+ bytes

# %%
fig = go.Figure()
df_ind=df_gdp[df_gdp["Country Code"]=="IND"]

trace_ind = go.Bar(
    
    #x=df_ind_gdpcap[df_ind_bra_gdpcap["Country Code]==['Year'],
    x=df_ind['Year'],
    y=df_ind['value'],
    name ="India"
)
fig.add_trace(trace_ind)

df_bra=df_gdp[df_gdp["Country Code]=="BRA"]

trace_bra = go.Bar(
    
    x=df_bra['Year'],
    y=df_bra['value'],
    name = "Brazil"
)
fig.add_trace(trace_bra)



fig.update_layout(
    title = "India GDP per captia over time ",
    xaxis_title='Year',
    yaxis_title ='GDP per capita'
)

fig.show()
# Out:
#   File "<ipython-input-70-d01c0cee8eec>", line 13
#     df_bra=df_gdp[df_gdp["Country Code]=="BRA"]
#                                             ^
# SyntaxError: invalid syntax

# %%
fig = px.bar(
    data_frame = df_ind_gdpcap,
    title="India GDP per capita over time",
    labels={"value":"GDP per capita","Year":"YEAR"},
    orientation="v",
    x='Year',
    y='value'
)

fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9d83e534-d073-4722-b3b1-af036d025a43" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9d83e534-d073-4722-b3b1-af036d025a43")) {
#                     Plotly.newPlot(
#                         '9d83e534-d073-4722-b3b1-af036d025a43',
# ...

# %%
df_ind_bra = df_gdp[df_gdp["Country Code"].isin(["IND","BRA"])]
df_ind_bra
# Out:
#      Unnamed: 0  Year  ...         Income Group Lending Type
# 140         140  2015  ...  Upper middle income         IBRD
# 141         141  2016  ...  Upper middle income         IBRD
# 142         142  2017  ...  Upper middle income         IBRD
# 143         143  2018  ...  Upper middle income         IBRD
# 144         144  2019  ...  Upper middle income         IBRD
# 145         145  2020  ...  Upper middle income         IBRD
# 462         462  2015  ...  Lower middle income         IBRD
# 463         463  2016  ...  Lower middle income         IBRD
# 464         464  2017  ...  Lower middle income         IBRD
# 465         465  2018  ...  Lower middle income         IBRD
# 466         466  2019  ...  Lower middle income         IBRD
# 467         467  2020  ...  Lower middle income         IBRD
#
# [12 rows x 9 columns]

# %%
fig = px.bar(
    data_frame = df_ind_bra,
    title="India GDP per capita over time",
    labels={"value":"GDP per capita","Year":"YEAR"},
    orientation="v",
    x='Year',
    y='value',
    color = "Country Code",
  
)

fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d28adf0c-97f4-4136-92fc-97bc07e3163a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d28adf0c-97f4-4136-92fc-97bc07e3163a")) {
#                     Plotly.newPlot(
#                         'd28adf0c-97f4-4136-92fc-97bc07e3163a',
# ...

# %%
fig = px.bar(
    data_frame = df_ind_bra,
    title="India GDP per capita over time",
    labels={"value":"GDP per capita","Year":"YEAR"},
    orientation="v",
    x='Year',
    y='value',
    color = "Country Code",
    barmode="group"
)

fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b58f851a-c434-4cfb-9168-92d01544ac37" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b58f851a-c434-4cfb-9168-92d01544ac37")) {
#                     Plotly.newPlot(
#                         'b58f851a-c434-4cfb-9168-92d01544ac37',
# ...

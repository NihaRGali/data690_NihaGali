# %% [markdown]
# <a href="https://colab.research.google.com/github/NihaRGali/data690_NihaGali/blob/main/assignment_09/Inclass_practice_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### In_class_practice_09
# - Name: Niha Reddy Gali
# - Date: 10/28/2021

# %%
import math_fuction as mf

# %%
a= input("enter a number: ")
# Out:
# enter a number: 100

# %%
print(a)
# Out:
# 100

# %%
b=input("enter a number:")
# Out:
# enter a number:100

# %%
print(b)
# Out:
# 100

# %%
c=mf.addition(a,b)
print(c)
# Out:
# 100100

# %%
a=23
b=50

c=mf.addition(a,b)

print(c)
# Out:
# 73

# %% [markdown]
# <a href="https://colab.research.google.com/github/NihaRGali/data690_NihaGali/blob/main/project_01/IndividualProject_A_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1 - "Butterfly Effect of Violence on Women "
#
# ![woman-education-related-post.jpg](data:image/jpeg;base64,...)- Professor : Wang
#
# - Student   : Niha Reddy Gali
#
# - Date      : 10-20-21

# %% [markdown]
# # Topics included :
#
# - Economy and Growth
# - Health
# - Education
#
#
# # Countries :
#
# - Afghanistan
# - Chad
# - Guatemala
# - Rwanda
# - Zimbabwe
#
#
# ### Analization is done from 2004-4015

# %% [markdown]
# # INTRODUCTION :
#
#   Violence inflicted in and outside the home the has adverse effects on individuals within the family and society in general both in emotional, physical, educational and economical wellbeing. So, there is a need to identify the reasons for the cause of such problems and then finding the right solution for proper functioning of the society.
#
#
#
# 1.   What are the reasons for accepting violent behavior ?
# 2.   What are the impacts if the problem is left unattended ?
# 3.   How it affects the future generations and economy ?
# 3.   What is/are the solution(s) ?
#
#
#
#  So to prove this, I have considered :
# - Health,Education,
# - Economy and Growth for two sets of countries with more and with less violence and various other attributes effecting the GDP.

# %% [markdown]
# # ANALYSIS :
#
#  On undersatnding the trends and patterns of occurance, I considered Health,Education, Economy and Growth for two sets of countries with more and with less violence and various other attributes effecting the GDP. I say everything is inter-related say from giving birth to a child - providing them good education - their contribution in service sector - countries GDP - Health - Self care - Mortality rate.

# %% [markdown]
# This chart represents the women shubjected to physical or sexual violence. This generally happens when both the genders are not being treated equally and one of them wants to maintain the supremacy.

# %% [markdown]
# ![newplot (7).png](data:image/png;base64,...)

# %% [markdown]
# However,  such type of injustice can be controlled if proper education is provided to both of them. So, let's have a look at the scenario of the gender that is being suppressed.

# %% [markdown]
# ## There are women who believe a husband is justified in beating his wife when :
# - She argues with him
# - She burns the food
# - She goes out without telling him
# - She neglects the children
# - She refuses sex with him

# %% [markdown]
# ![newplot (8).png](data:image/png;base64,...)

# %% [markdown]
# It is a heart breaking issue that even few women justify men for treating them this way. It can be probably because they are totally dependent on them or either ignorant. Both of these problems can be solved by providing them with proper education from their childhood.

# %% [markdown]
# ### Here is the chart representing health care access of women:
# - Not wanting to go alone
# - Getting money for treatment
# - Getting permission for treatment
#
# These graphs clearly represents how dependent women are on the men.

# %% [markdown]
# Also,

# %% [markdown]
# ![newplot (11).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (10).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (12).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (13).png](data:image/png;base64,...)

# %% [markdown]
# ### This irregularities in health care badly effects the health of the women by weakening them and by not getting proper medical facilities when needed.

# %% [markdown]
# ### So when they get married with these health conditions the next generation is going to get effected by the past mistakes.
#
# Below chart represents the number of infant deaths

# %% [markdown]
# ![newplot (14).png](data:image/png;base64,...)

# %% [markdown]
# ### Infant deaths also depend on the care and vaccinations, mal nutrition given to them. Proper vaccination helps in keeping the baby healthy. Due to lack of knowledge regarding the importance of vaccination and resources parents do not know what to feed the children and thereby resulting in piling up their lives to death.

# %% [markdown]
# It is the responsibility of the parents to take care of the kids and provide healthy nutrition and good health for their better future.

# %% [markdown]
# ### On understanding the scenario, I wanted to know the percentage of women population in these countries. Shockingly, i found that 48-50% ot the total population are females and conlcuded that
#  - If 50% of the population are not being given proper education, health, emotional support,financial support , how can they be a proper example for the furture generations ?
#  - How do we expect the next generation to be healthy ?

# %% [markdown]
# ![newplot (21).png](data:image/png;base64,...)

# %% [markdown]
# Out of the 50% of female population, it is clear that the school life expectancy is almost 6 in Chad which turns out to be the downfall for a growing society.

# %% [markdown]
# ![newplot (22).png](data:image/png;base64,...)

# %% [markdown]
# Interestingly almost 70% of the women of Chad are being married by the age 18. It turns out that most of the girls are not being given a chance for education.

# %% [markdown]
# ![newplot (20).png](data:image/png;base64,...)

# %% [markdown]
# This comparision turns out to have a drastic importance in economy. It is because 50% of the population is not being given the right to education and right to live on their own.

# %% [markdown]
# ![newplot (25).png](data:image/png;base64,...)

# %% [markdown]
# So, let's have a look at the countries with great GDP.

# %% [markdown]
# ![newplot (26).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (27).png](data:image/png;base64,...)

# %% [markdown]
# ### CONCLUSION :
# When compared to school life expectancy with previous countries, developed countries have more life expectancy and with no huge differences between Male and Female education. The contribution to economy from both the genders is almost the same.
#
# So, in order to reduce the above mentioned violence, health, low GDP probemsfor Afghanistan,  Zimbabwe, Chad, Rwanda, Guatemala is that :
# - Women contributes to 50% in those countries
# - Providing them better education helps in better life - better economy- better health - better care for children - No Malnutrition - No Deaths - High Mortality Rate.
